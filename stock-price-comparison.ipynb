# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv('/content/TATAMOTORS.csv')

# %%
df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03  TELCO     EQ      201.60  207.4  217.25  207.4  217.0  216.75
# 1  2000-01-04  TELCO     EQ      216.75  217.0  219.00  206.0  211.9  208.20
# 2  2000-01-05  TELCO     EQ      208.20  194.0  217.80  194.0  213.1  213.25
# 3  2000-01-06  TELCO     EQ      213.25  215.0  229.90  215.0  222.0  222.10
# 4  2000-01-07  TELCO     EQ      222.10  224.0  239.90  223.1  239.9  239.90
#
#      VWAP   Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  214.28   676126  1.448775e+13     NaN                 NaN          NaN
# 1  209.50   679215  1.422962e+13     NaN                 NaN          NaN
# 2  210.33  1120951  2.357684e+13     NaN                 NaN          NaN
# 3  225.29  1968998  4.435932e+13     NaN                 NaN          NaN
# 4  236.32  2199431  5.197636e+13     NaN                 NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %%
fig = px.line(df, x='Date', y="Open")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df.Date.min())
print(df.Date.max())
# Out:
# 2000-01-03
# 2021-04-30

# %%
df.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
df
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low  \
# 0     2000-01-03       TELCO     EQ      201.60  207.4  217.25  207.40
# 1     2000-01-04       TELCO     EQ      216.75  217.0  219.00  206.00
# 2     2000-01-05       TELCO     EQ      208.20  194.0  217.80  194.00
# 3     2000-01-06       TELCO     EQ      213.25  215.0  229.90  215.00
# 4     2000-01-07       TELCO     EQ      222.10  224.0  239.90  223.10
# ...          ...         ...    ...         ...    ...     ...     ...
# 5301  2021-04-26  TATAMOTORS     EQ      294.00  297.0  299.00  294.60
# 5302  2021-04-27  TATAMOTORS     EQ      295.40  295.7  302.50  295.10
# 5303  2021-04-28  TATAMOTORS     EQ      301.50  303.5  309.50  303.00
# 5304  2021-04-29  TATAMOTORS     EQ      305.90  308.9  310.00  301.25
# 5305  2021-04-30  TATAMOTORS     EQ      301.90  298.2  301.30  292.55
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
df.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1,inplace=True)

# %%
df
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low  \
# 0     2000-01-03       TELCO     EQ      201.60  207.4  217.25  207.40
# 1     2000-01-04       TELCO     EQ      216.75  217.0  219.00  206.00
# 2     2000-01-05       TELCO     EQ      208.20  194.0  217.80  194.00
# 3     2000-01-06       TELCO     EQ      213.25  215.0  229.90  215.00
# 4     2000-01-07       TELCO     EQ      222.10  224.0  239.90  223.10
# ...          ...         ...    ...         ...    ...     ...     ...
# 5301  2021-04-26  TATAMOTORS     EQ      294.00  297.0  299.00  294.60
# 5302  2021-04-27  TATAMOTORS     EQ      295.40  295.7  302.50  295.10
# 5303  2021-04-28  TATAMOTORS     EQ      301.50  303.5  309.50  303.00
# 5304  2021-04-29  TATAMOTORS     EQ      305.90  308.9  310.00  301.25
# 5305  2021-04-30  TATAMOTORS     EQ      301.90  298.2  301.30  292.55
#
#         Last   Close    VWAP    Volume      Turnover
# 0     217.00  216.75  214.28    676126  1.448775e+13
# ...

# %%
df.isna().sum()
# Out:
# Date          0
# Symbol        0
# Series        0
# Prev Close    0
# Open          0
# High          0
# Low           0
# Last          0
# Close         0
# VWAP          0
# Volume        0
# Turnover      0
# dtype: int64

# %%
df.dtypes
# Out:
# Date           object
# Symbol         object
# Series         object
# Prev Close    float64
# Open          float64
# High          float64
# Low           float64
# Last          float64
# Close         float64
# VWAP          float64
# Volume          int64
# Turnover      float64
# dtype: object

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
ax = df[['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close']].plot(kind='box', title='boxplot')
plt.show()

# %%
Q1 = df['Prev Close'].quantile(0.25)
Q3 = df['Prev Close'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['Prev Close'] < lower) | (df['Prev Close'] > upper)].index, inplace = True)

plt.boxplot(df['Prev Close'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c931a7a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c931abc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c931a500>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c931b100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c931b3a0>],
#  'means': []}

# %%
Q1 = df['Open'].quantile(0.25)
Q3 = df['Open'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['Open'] < lower) | (df['Open'] > upper)].index, inplace = True)

plt.boxplot(df['Open'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c9498b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c94990c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c9498a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c9499600>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c94998a0>],
#  'means': []}

# %%
Q1 = df['High'].quantile(0.25)
Q3 = df['High'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['High'] < lower) | (df['High'] > upper)].index, inplace = True)

plt.boxplot(df['High'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c94eabf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c94eb130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c94ea950>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c94eb670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c94eb910>],
#  'means': []}

# %%
Q1 = df['Low'].quantile(0.25)
Q3 = df['Low'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['Low'] < lower) | (df['Low'] > upper)].index, inplace = True)

plt.boxplot(df['Low'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6fad180>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6fad5a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6facee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6fadae0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6fadd80>],
#  'means': []}

# %%
Q1 = df['Last'].quantile(0.25)
Q3 = df['Last'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['Last'] < lower) | (df['Last'] > upper)].index, inplace = True)

plt.boxplot(df['Last'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6ffb130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6ffb670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6ffae90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6ffbbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6ffbe50>],
#  'means': []}

# %%
Q1 = df['Close'].quantile(0.25)
Q3 = df['Close'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df.drop(df[(df['Close'] < lower) | (df['Close'] > upper)].index, inplace = True)

plt.boxplot(df['Close'])

from google.colab import files
df.to_csv('correct_one.csv')
files.download('correct_one.csv')

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
ax = df[['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close']].plot(kind='box', title='boxplot')
plt.show()

# %%
df
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low  \
# 0     2000-01-03       TELCO     EQ      201.60  207.4  217.25  207.40
# 1     2000-01-04       TELCO     EQ      216.75  217.0  219.00  206.00
# 2     2000-01-05       TELCO     EQ      208.20  194.0  217.80  194.00
# 3     2000-01-06       TELCO     EQ      213.25  215.0  229.90  215.00
# 4     2000-01-07       TELCO     EQ      222.10  224.0  239.90  223.10
# ...          ...         ...    ...         ...    ...     ...     ...
# 5301  2021-04-26  TATAMOTORS     EQ      294.00  297.0  299.00  294.60
# 5302  2021-04-27  TATAMOTORS     EQ      295.40  295.7  302.50  295.10
# 5303  2021-04-28  TATAMOTORS     EQ      301.50  303.5  309.50  303.00
# 5304  2021-04-29  TATAMOTORS     EQ      305.90  308.9  310.00  301.25
# 5305  2021-04-30  TATAMOTORS     EQ      301.90  298.2  301.30  292.55
#
#         Last   Close    VWAP    Volume      Turnover
# 0     217.00  216.75  214.28    676126  1.448775e+13
# ...

# %%
figure = px.bar(df,x="Date",y="Turnover",title="Bar Plot of Tata Motors")
figure.update_traces(marker_color = 'red')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df2 = pd.read_csv('/content/TATASTEEL.csv')

# %%
df2.head()
# Out:
#          Date Symbol Series  Prev Close    Open   High     Low    Last  \
# 0  2000-01-03  TISCO     EQ      142.35  148.00  153.2  146.10  152.50
# 1  2000-01-04  TISCO     EQ      152.45  150.10  153.0  143.05  151.95
# 2  2000-01-05  TISCO     EQ      150.80  144.60  162.9  144.60  158.00
# 3  2000-01-06  TISCO     EQ      156.55  158.95  169.1  158.95  169.00
# 4  2000-01-07  TISCO     EQ      168.25  173.40  179.0  166.30  170.55
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  152.45  150.92  2003185  3.023164e+13     NaN                 NaN
# 1  150.80  151.03  1555136  2.348785e+13     NaN                 NaN
# 2  156.55  156.85  3840284  6.023364e+13     NaN                 NaN
# 3  168.25  167.61  2560449  4.291530e+13     NaN                 NaN
# 4  171.95  173.89  3641691  6.332459e+13     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %%
fig = px.line(df2, x='Date', y="Open")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df2.Date.min())
print(df2.Date.max())
# Out:
# 2000-01-03
# 2021-04-30

# %%
df2.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
df2.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1,inplace=True)

# %%
df2.isna().sum()
# Out:
# Date          0
# Symbol        0
# Series        0
# Prev Close    0
# Open          0
# High          0
# Low           0
# Last          0
# Close         0
# VWAP          0
# Volume        0
# Turnover      0
# dtype: int64

# %%
df2.dtypes
# Out:
# Date           object
# Symbol         object
# Series         object
# Prev Close    float64
# Open          float64
# High          float64
# Low           float64
# Last          float64
# Close         float64
# VWAP          float64
# Volume          int64
# Turnover      float64
# dtype: object

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
ax = df2[['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close']].plot(kind='box', title='boxplot')
plt.show()

# %%
Q1 = df2['Prev Close'].quantile(0.25)
Q3 = df2['Prev Close'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['Prev Close'] < lower) | (df2['Prev Close'] > upper)].index, inplace = True)

plt.boxplot(df2['Prev Close'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6e06890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6e06dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6e065f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6e07310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6e075b0>],
#  'means': []}

# %%
Q1 = df2['Open'].quantile(0.25)
Q3 = df2['Open'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['Open'] < lower) | (df2['Open'] > upper)].index, inplace = True)

plt.boxplot(df2['Open'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6e57fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6c84520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6e57d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6c84a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6c84d00>],
#  'means': []}

# %%
Q1 = df2['High'].quantile(0.25)
Q3 = df2['High'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['High'] < lower) | (df2['High'] > upper)].index, inplace = True)

plt.boxplot(df2['High'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6cd1ba0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6cd1fc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6cd1900>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6cd2500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6cd27a0>],
#  'means': []}

# %%
Q1 = df2['Low'].quantile(0.25)
Q3 = df2['Low'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['Low'] < lower) | (df2['Low'] > upper)].index, inplace = True)

plt.boxplot(df2['Low'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c94d1990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6da6c20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c949bf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6da5e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6da6020>],
#  'means': []}

# %%
Q1 = df2['Last'].quantile(0.25)
Q3 = df2['Last'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['Last'] < lower) | (df2['Last'] > upper)].index, inplace = True)

plt.boxplot(df2['Last'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c6f13880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c6f13bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c6f11870>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c6f11ea0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c6f126e0>],
#  'means': []}

# %%
Q1 = df2['Close'].quantile(0.25)
Q3 = df2['Close'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR


df2.drop(df2[(df2['Close'] < lower) | (df2['Close'] > upper)].index, inplace = True)

plt.boxplot(df2['Close'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7932c703a9e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7932c703bac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7932c7038490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7932c703bdc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7932c703afb0>],
#  'means': []}

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
ax = df2[['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close']].plot(kind='box', title='boxplot')
plt.show()

# %%
figure = px.bar(df2,x="Date",y="Turnover",title="Bar Plot of Tata Motors")
figure.update_traces(marker_color = 'red')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line()

fig.add_scatter(x=df['Date'], y=df['Turnover'], name = "Tata Motors")
fig.add_scatter(x=df['Date'], y=df2['Turnover'], name = "Tata Steel")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line()

fig.add_scatter(x=df['Date'], y=df['High'], name = "Tata Motors")
fig.add_scatter(x=df['Date'], y=df2['High'], name = "Tata Steel")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Tata Steel Candlestick plot
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(x=df2['Date'],
                                    open=df2['Open'],
                                    high=df2['High'],
                                    low=df2['Low'],
                                    close=df2['Close'])])
fig.update_xaxes(rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
